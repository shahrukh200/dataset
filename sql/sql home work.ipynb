# %%
df = spark.read.format("csv").option("header","true").load("Files/supermart_sales/SupermartSales.csv")
# Out:
# StatementMeta(, 44cb1d04-7088-4f02-9343-999a1e22e6aa, 7, Finished, Available, Finished)

# %%
 df.createOrReplaceTempView("mytable")
# Out:
# StatementMeta(, 44cb1d04-7088-4f02-9343-999a1e22e6aa, 8, Finished, Available, Finished)

# %%
display(df)
# Out:
# StatementMeta(, bbdb772d-ae0a-4f9b-8710-252c367afb27, 6, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, ba35e55d-34d1-4f3d-8a62-2371be695dd9)

# %%
# %%sql
# SELECT count (Sales) , Region
# FROM mytable
# GROUP BY Region
# Out:
# StatementMeta(, f1ee894c-f024-4b52-ad81-5f9350610599, 6, Finished, Available, Finished)
# <Spark SQL result set with 5 rows and 2 fields>

# %%
# %%sql
# SELECT  Customer_Name, count (Order_Date)
# FROM mytable
# GROUP BY Customer_Name
# Out:
# StatementMeta(, f1ee894c-f024-4b52-ad81-5f9350610599, 21, Finished, Available, Finished)
# <Spark SQL result set with 50 rows and 2 fields>

# %%
# %%sql
# SELECT Discount
# FROM mytable
# WHERE (Discount>0.20) AND (Discount<0.30)
# Out:
# StatementMeta(, f1ee894c-f024-4b52-ad81-5f9350610599, 24, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 1 fields>

# %%
# %%sql
# SELECT Profit AS TOP3
# FROM mytable
# ORDER BY Profit DESC LIMIT 3
# Out:
# StatementMeta(, f1ee894c-f024-4b52-ad81-5f9350610599, 36, Finished, Available, Finished)
# <Spark SQL result set with 3 rows and 1 fields>

# %%
# %%sql
# SELECT Category,
# REPLACE(Category, "Snacks" , "Quick Bites")
# FROM mytable
# Out:
# StatementMeta(, f1ee894c-f024-4b52-ad81-5f9350610599, 43, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 2 fields>
